# %% [markdown]
# QUESTION 1. GUASSIAN PRIOR

# %% [markdown]
# QUESTION 2. IT'S GUARANTEED TO PREVENT OVERFITTING

# %% [markdown]
# QUESTION 3. REDUCES VARIANCE AT THE EXPENSE OF HIGHER BIAS.

# %% [markdown]
# QUESTION 4. VARIANCE

# %% [markdown]
# QUESTION 5. LEAST SQUARED ERROR

# %% [markdown]
# QUESTION 6. LINEAR REGRESSION IS SENSITIVE TO OUTLIERS

# %% [markdown]
# QUESTION 7. 2

# %% [markdown]
# QUESTION 8. DECREASES MODEL BIAS

# %% [markdown]
# QUESTION 9. THE MODEL IS PERFORMING WITH 75% ACCURACY

# %% [markdown]
# QUESTION 10. WEIGHTS HAVE A GUASSIAN ERROR.

# %% [markdown]
# QUESTION 11. HETEROSCEDESTICITY

# %%
#QUESTION 12
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn import preprocessing
from sklearn.metrics import r2_score   
from sklearn.model_selection import train_test_split 
from sklearn.preprocessing import MinMaxScaler
df = pd.read_csv(r'C:\Users\AMARA METU\Desktop\energydata_complete.csv')
df.head()
X = pd.DataFrame(df['T2'])
y = pd.DataFrame(df['T6'])
regressor = LinearRegression()
regressor.fit(X_train, y_train)
ypredtest = regressor.predict(X_test)
C = pd.DataFrame(ypredtest)
C
r2_score = r2_score(y_test, C)
round(r2_score, 2)
#df = df.drop(columns=['date', 'lights'])
#X = np.array(df.drop[0])
#X
#scaler = MinMaxScaler()
#df_normalize = scaler.fit_transform(df)
#df_normalize
#df_features = df.drop(columns=['Appliances'])
#df_features
#normalizing the features
#scaler = MinMaxScaler()
#df_normalize_of_features = scaler.fit_transform(df_features)
#df_target = df['Appliances']
#df_target
 
#X = np.array(df.drop[0])
#X
#scaler = MinMaxScaler()
# = scaler.fit_transform(df_drop)
#df_normalized
# Out:
# 0.64

# %%
#QUESTION 13
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn import preprocessing
from sklearn.metrics import r2_score   
from sklearn.model_selection import train_test_split 
from sklearn.preprocessing import MinMaxScaler
df = pd.read_csv(r'C:\Users\AMARA METU\Desktop\energydata_complete.csv')
df.head()
dx = df['Appliances']
dx
df = df.drop(columns=['date', 'lights', 'Appliances'], axis = 1)
df
#dx = df['Appliances']
#dx
#X = df
scaler = MinMaxScaler()
df_normalize_features = pd.DataFrame(scaler.fit_transform(df))
df_normalize_features
X = np.array(df_normalize_features)
y = np.array(dx)
#df_features = df.drop(columns=['Appliances'])
#df_features
#normalizing the target
#X = df_normalize_features
#y = 
#X = np.array(df.drop[0])
#X
#scaler = MinMaxScaler()
#df_normalized= pd.DataFrame(scaler.fit_transform(dx))
#df_normalized.reshape(-1, 1)

#df
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42) 
regressor = LinearRegression()
regressor.fit(X_train, y_train)
ypredtest = regressor.predict(X_test)

# %% [markdown]
# QUESTION 17. RH_2 RH_1
# QUESTION 18. YES
# QUESTION 19. 4

# %%
df.describe()
# Out:
#                  T1          RH_1            T2          RH_2            T3  \
# count  19735.000000  19735.000000  19735.000000  19735.000000  19735.000000
# mean      21.686571     40.259739     20.341219     40.420420     22.267611
# std        1.606066      3.979299      2.192974      4.069813      2.006111
# min       16.790000     27.023333     16.100000     20.463333     17.200000
# 25%       20.760000     37.333333     18.790000     37.900000     20.790000
# 50%       21.600000     39.656667     20.000000     40.500000     22.100000
# 75%       22.600000     43.066667     21.500000     43.260000     23.290000
# max       26.260000     63.360000     29.856667     56.026667     29.236000
#
#                RH_3            T4          RH_4            T5          RH_5  \
# count  19735.000000  19735.000000  19735.000000  19735.000000  19735.000000
# mean      39.242500     20.855335     39.026904     19.592106     50.949283
# ...

# %%
df.dtypes
# Out:
# date            object
# Appliances       int64
# lights           int64
# T1             float64
# RH_1           float64
# T2             float64
# RH_2           float64
# T3             float64
# RH_3           float64
# T4             float64
# RH_4           float64
# T5             float64
# RH_5           float64
# T6             float64
# RH_6           float64
# T7             float64
# RH_7           float64
# T8             float64
# RH_8           float64
# T9             float64
# RH_9           float64
# T_out          float64
# Press_mm_hg    float64
# RH_out         float64
# Windspeed      float64
# Visibility     float64
# Tdewpoint      float64
# rv1            float64
# rv2            float64
# dtype: object

# %%
df.corr(method = 'pearson')
# Out:
#              Appliances    lights        T1      RH_1        T2      RH_2  \
# Appliances     1.000000  0.197278  0.055447  0.086031  0.120073 -0.060465
# lights         0.197278  1.000000 -0.023528  0.106968 -0.005622  0.050985
# T1             0.055447 -0.023528  1.000000  0.164006  0.836834 -0.002509
# RH_1           0.086031  0.106968  0.164006  1.000000  0.269839  0.797535
# T2             0.120073 -0.005622  0.836834  0.269839  1.000000 -0.165610
# RH_2          -0.060465  0.050985 -0.002509  0.797535 -0.165610  1.000000
# T3             0.085060 -0.097393  0.892402  0.253230  0.735245  0.137319
# RH_3           0.036292  0.131161 -0.028550  0.844677  0.121497  0.678326
# T4             0.040281 -0.008859  0.877001  0.106180  0.762066 -0.047304
# RH_4           0.016965  0.114936  0.097861  0.880359  0.231563  0.721435
# T5             0.019760 -0.078745  0.885247  0.205797  0.720550  0.110409
# RH_5           0.006955  0.141233 -0.014782  0.303258  0.029595  0.250271
# ...
